# %%
import pandas as pd
url="/home/shafeen/Documents/My-all-programs--/Probability&&Statistics with python/stat-env/nhanes_2015_2016.csv"
df=pd.read_csv(url)
df=pd.DataFrame(df)
df
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     83732     1.0     NaN     1.0       1         1        62         3
# 1     83733     1.0     NaN     6.0       1         1        53         3
# 2     83734     1.0     NaN     NaN       1         1        78         3
# 3     83735     2.0     1.0     1.0       2         2        56         3
# 4     83736     2.0     1.0     1.0       2         2        42         4
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5730  93695     2.0     2.0     NaN       1         2        76         3
# 5731  93696     2.0     2.0     NaN       2         1        26         3
# 5732  93697     1.0     NaN     1.0       1         2        80         3
# 5733  93700     NaN     NaN     NaN       1         1        35         3
# 5734  93702     1.0     NaN     2.0       2         2        24         3
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
wgt=df['BMXWT']
wgt
# Out:
# 0        94.8
# 1        90.4
# 2        83.4
# 3       109.8
# 4        55.2
#         ...
# 5730     59.1
# 5731    112.1
# 5732     71.7
# 5733     78.2
# 5734     58.3
# Name: BMXWT, Length: 5735, dtype: float64

# %%
plt.figure(figsize=(20,5))
x=range(df['BMXWT'].size)
y=wgt
plt.scatter(x,y,marker='x',s=0.5)
plt.title("Weight of every Individual")
plt.xlabel("Weight")
plt.ylabel("Frequency")
p1=(0,75)
p2=(6000,75)
x_c, y_c=zip(p1,p2)
plt.plot(x_c,y_c,color='red',linewidth=0.75)
plt.show()

# %%
wgt.mean()
# Out:
# 81.34267560889516

# %%
plt.figure(figsize=(20,5))
x=range(df['BMXWT'].size)
y=df['BMXWT']
plt.scatter(x,y,marker='*',s=1)
plt.title("Weight of every Individual")
plt.xlabel("Weight")
plt.ylabel("Frequency")
#the mean i think
x_c, y_c=([0,6000],[75,75])
plt.plot(x_c,y_c,color='red',linewidth=0.85)
#the mean the function provided
x_c, y_c=([0,6000],[wgt.mean(),wgt.mean()])
plt.plot(x_c,y_c,color='green',linewidth=2)
plt.show()

# %%
# understanding mean
import numpy as np
x=np.array([3,4,9,17,18,20,22,23,29,32,39,42,42,42,51,97])
np.mean(x)
# Out:
# 30.625

# %%
# different kind of average which is called the median

# %%
# finding the median to prove that outlier does not affect it
np.median(x) 
#median is same even if we change values in the array in the start or in the end
# Out:
# 26.0

# %%
# visualizing the data set weights

# %%
wgt.min()
# Out:
# 32.4

# %%
wgt.mean()
# Out:
# 81.34267560889516

# %%
wgt.median()
# Out:
# 78.2

# %% [markdown]
# Quartiles and Boxplots

# %%
num=np.array([3, 4, 9, 17, 18, 20, 22, 23, 29, 32, 39, 42, 42, 42, 51, 97])
np.median(num)
# Out:
# 26.0

# %%
import statistics
statistics.quantiles(num,n=4)
# Out:
# [17.25, 26.0, 42.0]

# %%
statistics.quantiles(wgt,n=4)
# Out:
# [43.7, 52.5, 50.1]

# %%
# %pip install seaborn
import seaborn as sns
ax=sns.boxplot(x=wgt)

# %%
male_wgt=df.loc[df['RIAGENDR']==2,'BMXWT']
male_wgt
# Out:
# 3       109.8
# 4        55.2
# 5        64.4
# 7        64.5
# 12       71.2
#         ...
# 5724     58.2
# 5727     64.8
# 5730     59.1
# 5732     71.7
# 5734     58.3
# Name: BMXWT, Length: 2976, dtype: float64

# %%
female_wgt=df.loc[df['RIAGENDR']==1,'BMXWT']
female_wgt
# Out:
# 0        94.8
# 1        90.4
# 2        83.4
# 6        76.6
# 8        72.4
#         ...
# 5726     78.7
# 5728     89.5
# 5729     39.2
# 5731    112.1
# 5733     78.2
# Name: BMXWT, Length: 2759, dtype: float64

# %%
plt.figure(figsize=(4,8))
sns.set_style("darkgrid")
ax=sns.boxplot(x="RIAGENDR",y="BMXWT",data=df,palette="Set3")
# Out:
# /tmp/ipykernel_11859/3048245493.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.boxplot(x="RIAGENDR",y="BMXWT",data=df,palette="Set3")

# %%
#easier way to do the same work
plt.figure(figsize=(4,8))
sns.set_style("dark")
ax = sns.boxplot(x="HIQ210",y="BMXWT",data=df,palette="Set3")
