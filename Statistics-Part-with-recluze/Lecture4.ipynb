# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
import pandas as pd
url="/home/shafeen/Documents/My-all-programs--/Probability&&Statistics with python/stat-env/nhanes_2015_2016.csv"
df=pd.read_csv(url)
df=pd.DataFrame(df)
df
# Out:
#        SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0     83732     1.0     NaN     1.0       1         1        62         3
# 1     83733     1.0     NaN     6.0       1         1        53         3
# 2     83734     1.0     NaN     NaN       1         1        78         3
# 3     83735     2.0     1.0     1.0       2         2        56         3
# 4     83736     2.0     1.0     1.0       2         2        42         4
# ...     ...     ...     ...     ...     ...       ...       ...       ...
# 5730  93695     2.0     2.0     NaN       1         2        76         3
# 5731  93696     2.0     2.0     NaN       2         1        26         3
# 5732  93697     1.0     NaN     1.0       1         2        80         3
# 5733  93700     NaN     NaN     NaN       1         1        35         3
# 5734  93702     1.0     NaN     2.0       2         2        24         3
#
#       DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
#Discrete Values

# %%
gender=df['RIAGENDR']
gender.value_counts()
# Out:
# RIAGENDR
# 2    2976
# 1    2759
# Name: count, dtype: int64

# %%
gender.value_counts().plot(kind="bar")
plt.show()

# %%
gender.value_counts().plot(kind="bar")
plt.xlabel("Gender")
plt.ylabel("frequency")
plt.xticks([0,1],["Male","Female"])
plt.show()

# %%
# Most Common Value

# %%
sizes=np.array([22,24,28,26,29,30,31,35,34,36,39,35,37,38,40,41,42,42,42,42,42,42,42,42,44,45,49,48,47,50,52,53,54,56,57,59,60,64,65,62,63,61,68,67,69,70,72,73,71,79,78,75,76,80,81,82,83,84,85])
sizes.mean()
# Out:
# 53.271186440677965

# %%
from collections import Counter
# we can use both ways to find the most common values in the dataset for further finding the appropriate average
count=Counter(sizes)
# for i in sizes:
#     count[i]+=1
count.most_common()
# Out:
# [(42, 8),
#  (35, 2),
#  (22, 1),
#  (24, 1),
#  (28, 1),
#  (26, 1),
#  (29, 1),
#  (30, 1),
#  (31, 1),
#  (34, 1),
#  (36, 1),
#  (39, 1),
#  (37, 1),
#  (38, 1),
#  (40, 1),
#  (41, 1),
#  (44, 1),
#  (45, 1),
#  (49, 1),
#  (48, 1),
#  (47, 1),
#  (50, 1),
#  (52, 1),
#  (53, 1),
#  (54, 1),
#  (56, 1),
#  (57, 1),
#  (59, 1),
#  (60, 1),
#  (64, 1),
#  (65, 1),
#  (62, 1),
#  (63, 1),
#  (61, 1),
#  (68, 1),
#  (67, 1),
#  (69, 1),
#  (70, 1),
#  (72, 1),
#  (73, 1),
#  (71, 1),
#  (79, 1),
#  (78, 1),
#  (75, 1),
#  (76, 1),
#  (80, 1),
#  (81, 1),
#  (82, 1),
#  (83, 1),
#  (84, 1),
#  (85, 1)]

# %%
# now we can also use scipy whihc is used to scientific computations in python

# %%
from scipy import stats
stats.mode(sizes)
# Out:
# ModeResult(mode=42, count=8)

# %%
gender.mode() # pandas mode function
# Out:
# 0    2
# Name: RIAGENDR, dtype: int64

# %%
stats.mode(gender) # scipy's mode function
# Out:
# ModeResult(mode=2, count=2976)

# %%
df['HIQ210'].unique() #
# Out:
# array([ 2., nan,  1.,  9.])

# %%
df['HIQ210'].value_counts().plot(kind="bar")
plt.show()

# %%
df['HIQ210'].value_counts().plot(kind="pie")
plt.show()

# %%
# continous or real - valued data

# %%
wgt=df['BMXWT']

# %%
wgt.value_counts().plot(kind="bar") #this deos not work at all
plt.show()

# %%
wgt.hist(bins=18)
plt.show()

# %%
# custom histogram Histogram for more flexibility

# %%
plt.hist(wgt,bins=30)
plt.xlabel('weight')
plt.ylabel('Individuals')
plt.title("Histogram of Weights in NHANES Dataset")
plt.grid()
plt.show()

# %%
# !pip install seaborn

# %%
import seaborn as sns
sns.set(color_codes=True)
sns.set_style("white")

# %%
#different names of histogram
sns.distplot(wgt,bins=20)
plt.xlabel("Weight")
plt.ylabel("Frequency")
plt.title("Histogram of Weights in NHANES Dataset")
sns.despine(offset=10,trim=True)
# Out:
# /tmp/ipykernel_43456/2428917009.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(wgt,bins=20)
# /home/shafeen/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/shafeen/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
#Can also be done this way for the newer versions of seaborn
#different names of histogram
sns.displot(wgt,bins=20,kde=True)
plt.xlabel("Weight")
plt.ylabel("Frequency")
plt.title("Histogram of Weights in NHANES Dataset")
sns.despine(offset=10,trim=True)
# Out:
# /home/shafeen/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/shafeen/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/shafeen/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
